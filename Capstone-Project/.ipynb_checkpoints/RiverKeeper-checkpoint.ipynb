# %%
# Jen Benson, RiverKeeper

# %%
import pandas as pd
import numpy as np

# %%
river2018 = pd.read_csv('Sweep Data Collection 2018.csv')
river2018
# Out:
#                            Name of Data Collection Site  \
# 0     Montgomery: Wallkill River Cleanup from\nRiver...
# 1     Esopus: Lighthouse Park and Esopus Meadows Cle...
# 2                     Matthiessen & Scenic Hudson Parks
# 3                                  Kingston Point Beach
# 4                                           Waryas Park
# 5                 Irvington: Scenic Hudson Park Cleanup
# 6                                        Kaal Rock Park
# 7                       John V. Lindsay Easy River Park
# 8                                          Flushing Bay
# 9      Greenpoint/Bushwick: Bushwick Inlet Park Cleanup
# 10                      Esopus: The Mount Beach Cleanup
# 11                                                Total
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# ...

# %%
# NaN where there is no data. should stop after total row.
# Source: https://stackoverflow.com/questions/29314033/python-pandas-dataframe-remove-empty-cells
river2018.dropna(subset=["Name of Data Collection Site"], inplace=True)
river2018
# Out:
#                          Name of Data Collection Site  \
# 0   Montgomery: Wallkill River Cleanup from\nRiver...
# 1   Esopus: Lighthouse Park and Esopus Meadows Cle...
# 2                   Matthiessen & Scenic Hudson Parks
# 3                                Kingston Point Beach
# 4                                         Waryas Park
# 5               Irvington: Scenic Hudson Park Cleanup
# 6                                      Kaal Rock Park
# 7                     John V. Lindsay Easy River Park
# 8                                        Flushing Bay
# 9    Greenpoint/Bushwick: Bushwick Inlet Park Cleanup
# 10                    Esopus: The Mount Beach Cleanup
# 11                                              Total
#
#                      Approximate Address and Location  \
# 0   Riverfront Park\nRiverfront Park & Rt. 416\nRi...
# 1                     255 River Road, Ulster Park, NY
# 2                    1 Bridge St, Irvington, NY 10533
# ...

# %%
# total column is inaccurate in 2018 data. it is a copy of row 2 instead of a total.
river2018.drop(11)
river2018
# How to drop a column?
# Out:
#                          Name of Data Collection Site  \
# 0   Montgomery: Wallkill River Cleanup from\nRiver...
# 1   Esopus: Lighthouse Park and Esopus Meadows Cle...
# 2                   Matthiessen & Scenic Hudson Parks
# 3                                Kingston Point Beach
# 4                                         Waryas Park
# 5               Irvington: Scenic Hudson Park Cleanup
# 6                                      Kaal Rock Park
# 7                     John V. Lindsay Easy River Park
# 8                                        Flushing Bay
# 9    Greenpoint/Bushwick: Bushwick Inlet Park Cleanup
# 10                    Esopus: The Mount Beach Cleanup
# 11                                              Total
#
#                      Approximate Address and Location  \
# 0   Riverfront Park\nRiverfront Park & Rt. 416\nRi...
# 1                     255 River Road, Ulster Park, NY
# 2                    1 Bridge St, Irvington, NY 10533
# ...

# %%
river2018.loc["New Total"]=river2018.sum()
river2018

# I need to remove the previous Total column before doing a sum.
# Out:
#                                 Name of Data Collection Site  \
# 0          Montgomery: Wallkill River Cleanup from\nRiver...
# 1          Esopus: Lighthouse Park and Esopus Meadows Cle...
# 2                          Matthiessen & Scenic Hudson Parks
# 3                                       Kingston Point Beach
# 4                                                Waryas Park
# 5                      Irvington: Scenic Hudson Park Cleanup
# 6                                             Kaal Rock Park
# 7                            John V. Lindsay Easy River Park
# 8                                               Flushing Bay
# 9           Greenpoint/Bushwick: Bushwick Inlet Park Cleanup
# 10                           Esopus: The Mount Beach Cleanup
# 11                                                     Total
# New Total  Montgomery: Wallkill River Cleanup from\nRiver...
#
#                             Approximate Address and Location  \
# ...

# %%
river2018.columns
# Out:
# Index(['Name of Data Collection Site', 'Approximate Address and Location',
#        'Number of Data Collection Participants',
#        'Start Time (Please include AM/PM)', 'End Time (Please include AM/PM)',
#        'Type of Location',
#        'Approximate Size (in square feet of area cleanup during Sweep project)',
#        'Beverage Bottles (Plastic)', 'Beverage Bottles (Glass)',
#        'Beverage Cans (Metal)', 'Single-Use Plastic Bags', 'Other Platic Bags',
#        'Paper Bags', 'Cups & Plates (Paper)', 'Cups & Plates (Plastic)',
#        'Cups & Plates (Foam)', 'Cigarette Butts & Food Wrappers',
#        'Food Wrappers (candy, chips, etc.)',
#        'Take Out/Away Containers (Plastic)', 'Take Out/Away Containers (Foam)',
#        'Bottle Caps (Plastic)', 'Bottle Caps (Metal)', 'Lids (Plastic)',
#        'Straws/Stirrers', 'Forks, Knives, Spoons (Plastic)',
#        'Fishing Buoys, Pots, & Traps',
#        'Fishing Net & Pieces: Rope (1 yard/meter = 1 piece):',
# ...

# %%
river2017 = pd.read_csv('Sweep Data Collection 2017.csv')
river2017
# Out:
#           Name of Data Collection Site  \
# 0      John V. Lindsay Easy River Park
# 1                         Flushing Bay
# 2                           Plum Point
# 3                 Kingston Point Beach
# 4    Matthiessen & Scenic Hudson Parks
# 5                          Waryas Park
# 6                       Kaal Rock Park
# 7                                Total
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# ...

# %%
river2017.dropna(subset=["Name of Data Collection Site"], inplace=True)
river2017
# Out:
#         Name of Data Collection Site        Approximate Address and Location  \
# 0    John V. Lindsay Easy River Park                   East River at 6th St.
# 1                       Flushing Bay    \nFlushing Bay Promenade, Queens, NY
# 2                         Plum Point                       RT 9W New Windsor
# 3               Kingston Point Beach  Kingston Point Park Kingston, NY 12401
# 4  Matthiessen & Scenic Hudson Parks        1 Bridge St, Irvington, NY 10533
# 5                        Waryas Park                                     NaN
# 6                     Kaal Rock Park             Hendryk Drive, Poughkeepsie
# 7                              Total                                     NaN
#
#   Number of Data Collection Participants Start Time (Please include AM/PM)  \
# 0                                     18                          12:30 PM
# 1                                    NaN                               NaN
# ...

# %%
river2017.columns
# Out:
# Index(['Name of Data Collection Site', 'Approximate Address and Location',
#        'Number of Data Collection Participants',
#        'Start Time (Please include AM/PM)', 'End Time (Please include AM/PM)',
#        'Type of Location',
#        'Approximate Size (in square feet of area cleanup during Sweep project)',
#        'Beverage Bottles (Plastic)', 'Beverage Bottles (Glass)',
#        'Beverage Cans (Metal)', 'Single-Use Plastic Bags', 'Paper Bags',
#        'Cups & Plates (Paper)', 'Cups & Plates (Plastic)',
#        'Cups & Plates (Foam)', 'Cigarette Butts',
#        'Food Wrappers (candy, chips, etc.)',
#        'Take Out/Away Containers (Plastic)', 'Take Out/Away Containers (Foam)',
#        'Bottle Caps (Plastic)', 'Bottle Caps (Metal)', 'Lids (Plastic)',
#        'Straws/Stirrers', 'Forks, Knives, Spoons (Plastic)',
#        'Fishing Buoys, Pots, & Traps',
#        'Fishing Net & Pieces: Rope (1 yard/meter = 1 piece):',
# ...

# %%
river2016 = pd.read_csv('Sweep Data Collection 2016.csv')
river2016
# Out:
#   Name of Data Collection Site  \
# 0           Hastings on Hudson
# 1                 Flushing Bay
# 2         Plum Point, Cornwall
# 3        Mount Academy, Esopus
# 4   Vassar College, Casperkill
# 5                        TOTAL
#
#                     Approximate Address and Location  \
# 0                 1 River St. Hastings on Hudson, NY
# 1  Worlds Fair Marina, Flushing Bay Queens, New York
# 2             Plum Point Park, New Windsor, NY 12553
# 3                          1001 Broadway, Esopus, NY
# 4            124 Raymond Ave, Poughkeepsie, NY 12604
# 5                                                NaN
#
#   Number of Data Collection Participants Start Time (Please include AM/PM)  \
# 0                                      6                           2:00 PM
# 1   20 Forms returned/approx. 210 people                                 5
# 2                                      8                           9:00 AM
# ...

# %%
river2016.columns
# Out:
# Index(['Name of Data Collection Site', 'Approximate Address and Location',
#        'Number of Data Collection Participants',
#        'Start Time (Please include AM/PM)', 'End Time (Please include AM/PM)',
#        'Type of Location',
#        'Approximate Size (in square feet of area cleanup during Sweep project)',
#        'Single-Use Plastic Bags', 'Paper Bags', 'Cups & Plates (Paper)',
#        'Cups & Plates (Plastic)', 'Cups & Plates (Foam)', 'Cigarette Butts',
#        'Food Wrappers (candy, chips, etc.)',
#        'Take Out/Away Containers (Plastic)', 'Take Out/Away Containers (Foam)',
#        'Forks, Knives, Spoons (Plastic)', 'Fishing Buoys, Pots, & Traps',
#        'Fishing Net & Pieces: Rope (1 yard/meter = 1 piece):',
#        'Fishing Line (1 yard/meter = 1 piece):', 'Worm containers',
#        '6-Pack Holders', 'Other Plastic/Foam Packaging',
#        'Other Plastic Bottles (oil, bleach, etc)', 'Strapping Bands',
# ...

# %%
# Collection Sites
river2018["Name of Data Collection Site"]
# Out:
# 0     Montgomery: Wallkill River Cleanup from\nRiver...
# 1     Esopus: Lighthouse Park and Esopus Meadows Cle...
# 2                     Matthiessen & Scenic Hudson Parks
# 3                                  Kingston Point Beach
# 4                                           Waryas Park
# 5                 Irvington: Scenic Hudson Park Cleanup
# 6                                        Kaal Rock Park
# 7                       John V. Lindsay Easy River Park
# 8                                          Flushing Bay
# 9      Greenpoint/Bushwick: Bushwick Inlet Park Cleanup
# 10                      Esopus: The Mount Beach Cleanup
# 11                                                Total
# Name: Name of Data Collection Site, dtype: object

# %%
river2017["Name of Data Collection Site"]
# Out:
# 0      John V. Lindsay Easy River Park
# 1                         Flushing Bay
# 2                           Plum Point
# 3                 Kingston Point Beach
# 4    Matthiessen & Scenic Hudson Parks
# 5                          Waryas Park
# 6                       Kaal Rock Park
# 7                                Total
# Name: Name of Data Collection Site, dtype: object

# %%
river2016["Name of Data Collection Site"]
# Out:
# 0            Hastings on Hudson
# 1                  Flushing Bay
# 2          Plum Point, Cornwall
# 3         Mount Academy, Esopus
# 4    Vassar College, Casperkill
# 5                         TOTAL
# Name: Name of Data Collection Site, dtype: object
